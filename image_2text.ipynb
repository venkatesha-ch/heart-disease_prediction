# %%
from PIL import Image
import pytesseract 
from pytesseract import *
print(pytesseract.image_to_string('test.jpg'))
print(pytesseract.image_to_string(Image.open('test.jpg'), lang = 'en', config = None, nice = 0, timeout = 0.5))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     225     try:
# --> 226         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     227     except OSError as e:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %%
pytesseract.tesseract_cmd = r'C:\Users\chven\Desktop\heart_disease_prediction'

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-4-135cb257cfd2> in <module>
# ----> 1 print(pytesseract.image_to_string(Image.open('test.jpg'), lang = 'en', config = None, nice = 0, timeout = 0.5))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     346         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     347         Output.STRING: lambda: run_and_get_output(*args),
# --> 348     }[output_type]()
#     349
#     350
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     345         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     346         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 347         Output.STRING: lambda: run_and_get_output(*args),
# ...

# %%
Image.open('test.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=362x152 at 0x1943D89FDD8>

# %%
pt.image_to_string(Image.open('test.jpg'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f8f5a0434271> in <module>
# ----> 1 pt.image_to_string(Image.open('test.jpg'))
#
# NameError: name 'pt' is not defined

# %%
temp = pytesseract.run_and_get_output('test.jpg')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-6f28d104f606> in <module>
# ----> 1 temp = pytesseract.run_and_get_output('test.jpg')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     256         }
#     257
# --> 258         run_tesseract(**kwargs)
#     259         filename = kwargs['output_filename_base'] + extsep + extension
#     260         with open(filename, 'rb') as output_file:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     227     except OSError as e:
#     228         if e.errno != ENOENT:
# --> 229             raise e
#     230         raise TesseractNotFoundError()
#     231
#
# ...
